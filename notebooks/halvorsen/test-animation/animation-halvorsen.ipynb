# %% [markdown]
# ### Imports et configuration

# %%
# %matplotlib widget

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### Animation 3D

# %%
# Chargement de la trajectoire simulée
trajectory = np.load('halvorsen-results.npz')
t = trajectory['t']
[x, y, z] = trajectory['X']

# Initialisation de la figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Configuration de la vue
ax.set_xlim([min(x), max(x)])
ax.set_ylim([min(y), max(y)])
ax.set_zlim([min(z), max(z)])
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Ligne pour la trajectoire et point pour la position actuelle
line, = ax.plot([], [], [], lw=2)
point, = ax.plot([], [], [], 'ro')  # point rouge

# Fonction d'initialisation
def init():
    line.set_data([], [])
    line.set_3d_properties([])
    point.set_data([], [])
    point.set_3d_properties([])
    return line, point

# Fonction d’animation
def update(frame):
    line.set_data(x[:frame], y[:frame])
    line.set_3d_properties(z[:frame])
    
    point.set_data([x[frame]], [y[frame]])
    point.set_3d_properties([z[frame]])
    
    return line, point


ani = FuncAnimation(fig, update, frames=len(t), init_func=init,
                    interval=18, blit=False)

# plt.show()

# %%
# (Reprends le code d’animation ici, ou place ceci à la fin)

from matplotlib.animation import FFMpegWriter

# Définir le writer vidéo
writer = FFMpegWriter(fps=30, bitrate=1800)

# Enregistrement en MP4
ani.save("animation_3d.mp4", writer=writer)
